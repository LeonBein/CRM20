# %%
# %load_ext autoreload
# %autoreload 2

# %%
import repoAnalysis

# %%
testRepoTuple = ('brockn', 'incubator-parquet-mr', 11108627)
repoAnalysis.calculateDeltaMetrics(testRepoTuple)
# Out:
# Time used for ('brockn', 'incubator-parquet-mr', 11108627): 18.34257936477661
#                                            sha  \
# 0     69ba4844730426a212c609facd93b33bf6692b3a
# 1     be1222ef4a3260ddcf516d73c6ceecd144a134cb
# 2     da9129927bce90feb6d2860745263f4d74d0dfa8
# 3     0b17cbee9541998df66d33c8a99b675ced80d9aa
# 4     bf20abbf4825fa5892d8e15c066e768671a39289
# ...                                        ...
# 1449  5fb63e9a0743a23735f5b6043abd202a85173202
# 1450  dbbf9443ffe219862c9744806f34deb2606d21c7
# 1451  24028799609ef606359d6bee39acd34d8d67a067
# 1452  f3cdad30930c2cd73404804cf4ceeca237509a2c
# 1453  a8c10efccf35977193cab80b0f17d6a2f7d066d9
#
#                                         parent   timestamp   repo_id  \
# 0     be1222ef4a3260ddcf516d73c6ceecd144a134cb  1412699955  11108627
# 1     da9129927bce90feb6d2860745263f4d74d0dfa8  1412198064  11108627
# 2     0b17cbee9541998df66d33c8a99b675ced80d9aa  1412196285  11108627
# ...
